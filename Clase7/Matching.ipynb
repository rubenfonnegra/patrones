# %% [markdown]
# # **Template Matching**

# %%
#@markdown --------------- 
#@markdown #### **Descargar archivos necesarios** 

# !pip install -qq gdown
# !gdown -qq "https://drive.google.com/uc?id=1zGoaI6TsylaUnHKNhuxb3_fTWYzVT8ct" -O sample_images.zip
# !unzip -qq /content/sample_images.zip -d /content/
# !rm -r /content/sample_images.zip
#@markdown ---------------

# %% [markdown]
# ## Example 1

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# Load original_golden_bridge.jpg
original = _

# Load portion_of_image.jpg
template = _

# %%
# Convert images to grayscale
gray_img = 
template = 

# Plot images
fig, (ax1, ax2) = plt.subplots(nrows=1, ncols=2, figsize=(15,10))
ax1.imshow(gray_img, cmap = 'gray'), ax1.set_title("Original"), ax1.set_axis_off() 
ax2.imshow(template, cmap = 'gray'), ax2.set_title("Template"), ax2.set_axis_off()

# %%
h, w = template.shape
img_result = cv2.cvtColor(original, cv2.COLOR_BGR2RGB)

result = cv2.matchTemplate(gray_img, template, cv2.TM_CCOEFF_NORMED)

loc = np.where(result >= 0.6)
for pt in zip(*loc[::-1]):
    cv2.rectangle(img_result, pt, (pt[0] + w, pt[1] + h), (0, 255, 0), 3)

# %%
# plot result
plt.figure(figsize = (15,10))
plt.imshow(img_result), plt.title("Original"), plt.axis("off")

# %% [markdown]
# ## Example 2

# %%
# Load simpsons.jpg
original = 

# Load barts_face.jpg
template =

# %%
# Convert images to grayscale
gray_img = 
template = 

# Plot images
fig, (ax1, ax2) = plt.subplots(nrows=1, ncols=2, figsize=(15,10))
ax1.imshow(gray_img, cmap = 'gray'), ax1.set_title("Original"), ax1.set_axis_off() 
ax2.imshow(template, cmap = 'gray'), ax2.set_title("Template"), ax2.set_axis_off()

# %%
h, w = template.shape
img_result = cv2.cvtColor(original, cv2.COLOR_BGR2RGB)

result = cv2.matchTemplate(gray_img, template, cv2.TM_CCOEFF_NORMED)
loc = np.where(result >= 0.6)
for pt in zip(*loc[::-1]):
    cv2.rectangle(img_result, pt, (pt[0] + w, pt[1] + h), (0, 255, 0), 3)

# %%
# plot result
plt.figure(figsize = (15,10))
plt.imshow(img_result), plt.title("Original"), plt.axis("off")

# %% [markdown]
# # **Matching multiple objects**

# %%
# Load super_mario.jpg
original = 

# Load super_mario_coin.jpg
template =

# %%
# Convert images to grayscale
gray_img = 
template = 

# Plot images
fig, (ax1, ax2) = plt.subplots(nrows=1, ncols=2, figsize=(15,10))
ax1.imshow(gray_img, cmap = 'gray'), ax1.set_title("Original"), ax1.set_axis_off() 
ax2.imshow(template, cmap = 'gray'), ax2.set_title("Template"), ax2.set_axis_off()

# %%
h, w = template.shape
img_result = cv2.cvtColor(original, cv2.COLOR_BGR2RGB)

result = cv2.matchTemplate(gray_img, template, cv2.TM_CCOEFF_NORMED)
loc = np.where(result >= 0.3)

for pt in zip(*loc[::-1]):
    cv2.rectangle(img_result, pt, (pt[0] + w, pt[1] + h), (0, 255, 0), 1)

# %%
plt.figure(figsize = (15,10))
plt.imshow(img_result), plt.title("Original"), plt.axis("off")

# %%
# Convert images to grayscale
gray_img = 

#change template using borders detection 
template_b = 

fig, (ax1, ax2) = plt.subplots(nrows=1, ncols=2, figsize=(15,10))
ax1.imshow(template, cmap = 'gray'), ax1.set_title("Original"), ax1.set_axis_off() 
ax2.imshow(template_b, cmap = 'gray'), ax2.set_title("Template"), ax2.set_axis_off()

# %%
h, w = template.shape
img_result = cv2.cvtColor(original, cv2.COLOR_BGR2RGB)
img_border = cv2.Canny(gray_img, 50, 255)

result = cv2.matchTemplate(img_border, template_b, cv2.TM_CCOEFF_NORMED)
loc = np.where(result >= 0.15)

for pt in zip(*loc[::-1]):
    cv2.rectangle(img_result, pt, (pt[0] + w, pt[1] + h), (255, 0, 0), 3)

# %%
plt.figure(figsize = (15,10))|
plt.imshow(img_result), plt.title("Original"), plt.axis("off")

# %% [markdown]
# ### bringing some image processing

# %%
# Convert images to grayscale
gray_img = 
template = 


#change template using borders detection 
canny_template = 

fig, (ax1, ax2) = plt.subplots(nrows=1, ncols=2, figsize=(15,10))
ax1.imshow( _ , cmap = 'gray'), ax1.set_title("Grayscaled"), ax1.set_axis_off() 
ax2.imshow( _ , cmap = 'gray'), ax2.set_title("Processed"), ax2.set_axis_off()

# %%
h, w = template.shape
img_result = cv2.cvtColor(original, cv2.COLOR_BGR2RGB)
gray_canny = cv2.Canny( _ , 50, 255)

result = cv2.matchTemplate(gray_canny, canny_template, cv2.TM_CCOEFF_NORMED)
loc = np.where(result >= _ )

for pt in zip(*loc[::-1]):
    cv2.rectangle(img_result, pt, (pt[0] + w, pt[1] + h), (255, 0, 0), 3)

# %%
fig, (ax1, ax2) = plt.subplots(nrows=1, ncols=2, figsize=(20,15))
ax1.imshow( _ , cmap = 'gray'), ax1.set_title("Borders"), ax1.set_axis_off() 
ax2.imshow( _ , cmap = 'gray'), ax2.set_title("Matching"), ax2.set_axis_off()

# %%
from skimage.feature import hog

# Convert images to grayscale
gray_img = _ 

#change template using borders detection 
_, hog_template = hog( _ , orientations=9, pixels_per_cell=( _ , _ ), visualize=True)
hog_template = np.array(hog_template, dtype="uint8")

fig, (ax1, ax2) = plt.subplots(nrows=1, ncols=2, figsize=(15,10))
ax1.imshow( _ , cmap = 'gray'), ax1.set_title("Original"), ax1.set_axis_off() 
ax2.imshow( _ , cmap = 'gray'), ax2.set_title("Template"), ax2.set_axis_off()

# %%
h, w = template.shape
img_result = cv2.cvtColor(original, cv2.COLOR_BGR2RGB)

_ , hog_img = hog( _ , orientations=9, pixels_per_cell=( _ , _ ), visualize=True)
hog_img = np.array( _ , dtype="uint8")

result = cv2.matchTemplate( _ , _ , cv2.TM_CCOEFF_NORMED)
loc = np.where(result >= _ )

for pt in zip(*loc[::-1]):
    cv2.rectangle(img_result, pt, (pt[0] + w, pt[1] + h), (255, 0, 0), 3)

# %%
fig, (ax1, ax2) = plt.subplots(nrows=1, ncols=2, figsize=(20,15))
ax1.imshow( _ , cmap = 'gray'), ax1.set_title("Borders"), ax1.set_axis_off() 
ax2.imshow( _ , cmap = 'gray'), ax2.set_title("Matching"), ax2.set_axis_off()

# %% [markdown]
# ## Multi-scale objects

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# Load super_mario.jpg and make border detection
original = _ 
gray = cv2.cvtColor( _ , cv2.COLOR_BGR2GRAY)
borders = _ 


# Load super_mario_coin.jpg
template = _ 
template = cv2.cvtColor( _ , cv2.COLOR_BGR2GRAY)

fig, (ax1, ax2) = plt.subplots(1,2, figsize = (16,5))
ax1.imshow( _ , cmap='gray'), ax1.set_title("Gray image"), ax1.set_axis_off() 
ax2.imshow( _ , cmap='gray'), ax2.set_title("Gray template"), ax2.set_axis_off()

# %%
# Make result image
img_result = cv2.cvtColor(original, cv2.COLOR_BGR2RGB)

for scale in np.linspace(0.8, 1.2, 50)[::-1]: # Multiscale 
	#
	# resize the image according to the scale, keeping aspect ratio
  height, width = int(template.shape[0] * scale), int(template.shape[1] * scale)
  template_resized = cv2.resize(template, (height, width))

	# if the resized template is bigger than the image, then break the loop
  if template_resized.shape[0] > borders.shape[0] or template_resized.shape[1] > borders.shape[1]:
    break

  # detect borders in the resized template and apply template matching
  template_resized_borders = _ 
  result = cv2.matchTemplate( _ , _ , cv2.TM_CCOEFF_NORMED)
  
  loc = np.where(result >= _ )
  # print (result.min(), result.max())

  for pt in zip(*loc[::-1]):
      cv2.rectangle(img_result, pt, (pt[0] + width, pt[1] + height), (255, 0, 0), 3)

# %%
image = cv2.cvtColor(original, cv2.COLOR_BGR2RGB)
plt.figure(figsize = (15,10))
plt.imshow(img_result), plt.title("Original"), plt.axis("off")

# %% [markdown]
# Replicate with the ```fractals.png``` and ```fractal_temp.png``` files
