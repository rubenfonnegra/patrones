# %% [markdown]
# # Estructurando datos en Python

# %%
import os
import cv2
import matplotlib.pyplot as plt

# %%
path = " _ "

list_ext = [ _ ]
list_files = []

_

print (list_files, "\n", len(list_files))

# %%
list_images = []

_

print(len(list_images))
# Out:
# 9

# %%
fig, axes = plt.subplots( _ , figsize = (30, 8))

_

# %% [markdown]
# # Estructurar audios

# %%
import librosa
from librosa.display import waveplot

# %%
audio, fm = librosa.load(" _ ")

# %%
waveplot(audio, fm)
