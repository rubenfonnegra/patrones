# %% [markdown]
# # **H**istogram of **O**riented **G**radients (HOG)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import numpy as np
import cv2
from matplotlib import pyplot as plt

# %%
# Take an image - sudoku4.jpg (grayscale)
img = 

laplacian = cv2.Laplacian( _ , cv2.CV_64F)
sobelx = cv2.Sobel( _ , cv2.CV_64F, 1, 0, ksize=5)
sobely = cv2.Sobel( _ , cv2.CV_64F, 0, 1, ksize=5)

# %%
plt.figure(figsize=(15,15))

plt.subplot(2,2,1), plt.title('Original'), plt.xticks([]), plt.yticks([])
plt.imshow( _ , cmap = 'gray')

plt.subplot(2,2,2), plt.title('Laplacian'), plt.xticks([]), plt.yticks([])
plt.title('Sobel X'), plt.imshow( _ ,cmap = 'gray')

plt.subplot(2,2,3), plt.xticks([]), plt.yticks([])
plt.imshow( _ ,cmap = 'gray')

plt.subplot(2,2,4), plt.title('Sobel Y'), plt.xticks([]), plt.yticks([])
plt.imshow( _ ,cmap = 'gray')

plt.show()
