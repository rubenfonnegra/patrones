# %% [markdown]
# # **H**istogram of **O**riented **G**radients (HOG)
#
# Images to use:
#   - [sudoku4.jpg](https://drive.google.com/file/d/1bxTtFUrykwYcyIbOZUs5AKQuTvvHGyxv/view?usp=sharing)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import numpy as np
import cv2
from matplotlib import pyplot as plt

# %%
# Take an image - sudoku4.jpg (grayscale)
img = 

# Edges in all directions
laplacian = cv2.Laplacian( _ , cv2.CV_64F)

# Edges in vertical or horizontal directions
sobelx = cv2.Sobel( _ , cv2.CV_64F, 1, 0, ksize=5)
sobely = cv2.Sobel( _ , cv2.CV_64F, 0, 1, ksize=5)

# %%
_, axes = plt.subplots (2,2, figsize = (15,15))
axes = axes.ravel()

axes[0].imshow( _ , cmap="gray")
axes[0].set_title('Original'),  axes[0].set_axis_off()

axes[1].imshow( _ , cmap="gray")
axes[1].set_title('Laplacian'), axes[1].set_axis_off()

axes[2].imshow( _ , cmap="gray")
axes[2].set_title('Sobel X'),   axes[2].set_axis_off()

axes[3].imshow( _ , cmap="gray")
axes[3].set_title('Sobel Y'),   axes[3].set_axis_off()
